# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_style("whitegrid")

# %%
# Load Data
df_eda = pd.read_csv("/Users/vaibhav/Desktop/data_analytics_projects/netflix_elt_project/data/raw/netflix_titles.csv")

print("\n First 5 rows:")
print(df_eda.head())
# Out:
#  First 5 rows:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Data Overview
print("\n Dataset Info:")
print(df_eda.info())

print("\n Summary Statistics:")
print(df_eda.describe(include='all'))

print("\n Missing Values:")
print(df_eda.isnull().sum())
# Out:
#  Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None
#
#  Summary Statistics:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# ...

# %%
# Data Cleaning
df_eda['director'].fillna('Unknown', inplace=True)
df_eda['cast'].fillna('Unknown', inplace=True)
df_eda['country'].fillna('Unknown', inplace=True)

df_eda['date_added'] = pd.to_datetime(df_eda['date_added'], errors='coerce')

# %%
# Analysis
# 1. Movies vs TV Shows
plt.figure()
df_eda['type'].value_counts().plot(kind='bar')
plt.title('Movies vs TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# 2. Top 10 Countries
plt.figure()
df_eda['country'].value_counts().head(10).plot(kind='barh')
plt.title('Top 10 Countries by Content')
plt.xlabel('Count')
plt.tight_layout()
plt.show()

# %%
# 3. Release Year Trend
plt.figure()
df_eda['release_year'].value_counts().sort_index().plot()
plt.title('Content Release Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# 4. Ratings Distribution
plt.figure()
df_eda['rating'].value_counts().plot(kind='bar')
plt.title('Ratings Distribution')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# 5. Most Common Genres
plt.figure()
df_eda['listed_in'].value_counts().head(10).plot(kind='barh')
plt.title('Top 10 Genres')
plt.xlabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Key Insights:
# - Movies are more common than TV Shows
# - Content production increased significantly after 2015
# - Few countries dominate content production
# - Drama and Comedy are among top genres
